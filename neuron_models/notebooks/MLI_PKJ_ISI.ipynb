# %% [markdown]
# <h2>Experiments with MLI
#     & PKJ ISIs<h2>

# %% [markdown]
# The goal of this experiment is to reciprically connect a network of MLI and PKJ neurons and observe the the change in ISI statistics given some set of synaptic weight values

# %% [markdown]
# Discussion: The mean and variance of spontaneous currents for MLI cells are the same.  The same holds for PKJ cells (but with different means and variances).  By connecting this network with MLI->MLI, MLI->PKJ and PKJ->MLI synapses, the mean firing rates of both MLI and PKJ cells decrease and the ISI variances increase, as observed in Hausser and Clark 1997.  The means are heavily affected by synaptic weights and number of synapses each neuron receives.  So, choosing the weights and number of synapses carefully one can achieve the target mean firing rate.  The variances of ISIs are more difficult.  Interestingly, the variance of MLI neurons increase substantially.  The coefficient of variation (CV) for MLI cells reaches ~.34 in this set up (~.40 in Hausser and Clark 1997 control).  Interestly, the ISI CV for PKJs stays rather low ~.23 here vs .49 in H&C 1997.  Additionaly, we see an increased asymmetry relative to GABA block in these simulations. Another interesting observation is that the PKJ->MLI synapses have a significant affect on the ISI variance in MLI cells: ISI variance without PKJ->MLI synapses falls to ~.26.
#
# By adding PKJ -> PKJ synapses, the ISI variance of PKJs increases substantially.
#
# By doing a crude parameter sweep, the following weight values get the network to very closely reproduce the results from H&C 1997 with the exception of PKJ firing rates: w_MLI_pkj =
# w_MLI_MLI =
# w_pkj_MLI =
# w_pkj_pkj =

# %%
# %load_ext autoreload
# %autoreload 2
import datetime
import os
from brian import *
import sys
sys.path.append('../../')
from neuron_models import *
import cPickle
import time
set_global_preferences(useweave=True, usenewpropagate=True, usecodegen=True, usecodegenweave=True)
defaultclock.dt = .5*ms
# Out:
# /home/bill/anaconda/lib/python2.7/site-packages/brian-1.4.0-py2.7.egg/brian/utils/sparse_patch/__init__.py:38: UserWarning: Couldn't find matching sparse matrix patch for scipy version 0.11.0, but in most cases this shouldn't be a problem.
#   warnings.warn("Couldn't find matching sparse matrix patch for scipy version %s, but in most cases this shouldn't be a problem." % scipy.__version__)

# %%
T = 60000
N_MLI = 16
N_PKJ = 16
MLI = MLIGroup(N_MLI)
PKJ = PurkinjeCellGroup(N_PKJ)
# Out:
# brian.stateupdater: WARNING  Using codegen CStateUpdater
# brian.stateupdater: WARNING  Using codegen CStateUpdater

# %%
# synaptic weights
w_mli_pkj = 0.#1.5#1.
w_mli_mli = 0.#2.#1.5
w_pkj_mli = 0.#1.0#3.
w_pkj_pkj = 0.#0.5#.5#3.5
# 2.5 2. 1.5 1.5 ~.8
#w_pkj_pkj	w_pkj_bs	w_bs_pkj	w_bs_bs
#0.5	 1.0	 2.0	 1.5

# Synapses
S_MLI_PKJ = Synapses(MLI,PKJ,model='w:1',pre='g_inh+=PKJ.g_inh_*w_mli_pkj')
S_MLI_MLI = Synapses(MLI,MLI,model='w:1',pre='g_inh+=MLI.g_inh_*w_mli_mli')
S_PKJ_MLI = Synapses(PKJ,MLI,model='w:1',pre='g_inh+=MLI.g_inh_*w_pkj_mli')
S_PKJ_PKJ = Synapses(PKJ,PKJ,model='w:1',pre='g_inh+=PKJ.g_inh_*w_pkj_pkj')

# Connections
S_MLI_PKJ[:,:] = 'minimum(abs(i-j),abs(abs(i-j)-N_PKJ))<=2' 
S_MLI_MLI[:,:] = '(minimum(abs(i-j),abs(abs(i-j)-N_MLI))<=2) & (i!=j)'
S_PKJ_MLI.connect_one_to_one()
S_PKJ_PKJ[:,:] = '(minimum(abs(i-j),abs(abs(i-j)-N_PKJ))<=1) & (i!=j)'

# %%
@network_operation(Clock(dt=1*ms))
def random_current():
    MLI_i = .0275 + .025*randn(len(MLI))
    MLI_i[MLI_i<0] = 0.0
    MLI.I = MLI_i * nA
    pkj_i = .0775 + .08*randn(len(PKJ))
    pkj_i[pkj_i<0] = 0.
    PKJ.I = pkj_i * nA

# %%
# Monitor
MS_MLI = SpikeMonitor(MLI)
MR_MLI = PopulationRateMonitor(MLI,bin=1*ms)
MISI_MLI = ISIHistogramMonitor(MLI,bins=arange(0,162,2)*ms)

MS_PKJ = SpikeMonitor(PKJ)
MR_PKJ = PopulationRateMonitor(PKJ,bin=1*ms)
MISI_PKJ = ISIHistogramMonitor(PKJ,bins=arange(0,162,2)*ms)

start = time.time()
run(T*msecond)
print time.time() - start
# Out:
# 51.1035859585

# %%
def isi_mean_and_std(monitor):
    '''
    compute the mean and variance of interspike intervals
    of a group of neurons
    '''
    isi = []
    for n_ind, times in monitor.spiketimes.iteritems():
        isi += list(diff(times)*1000)
    return mean(isi), var(isi)**.5

# %%
def simpleaxis(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()

# %%
fig = figure(figsize=(20,5))
ax = fig.add_subplot(121)
hist_plot(MISI_MLI, newfigure=False, color='w')
mew, std = isi_mean_and_std(MS_MLI)
#s = 'mean rate = %0.1f Hz\nmean ISI = %0.1f ms\nISI std = %0.1f ms\nCV = %0.2f' % (mean(MR_MLI.rate),mew,std,std/mew)
s = 'mean rate = %0.0f Hz\nCV = %0.2f' % (mean(MR_MLI.rate),std/mew)
annotate(s,(20,0),xytext=(95,MISI_MLI.count.max()*.7),xycoords='data',fontsize=24)
simpleaxis(ax)
tick_params(labelsize=20)
xlabel('ISI (ms)', fontsize=20)
ylabel('Count', fontsize=20)
#title('MLI ISI Histogram',fontsize=20)
xlim([0,200])


ax = fig.add_subplot(1,2,2)
hist_plot(MISI_PKJ, newfigure=False, color='k')
mew, std = isi_mean_and_std(MS_PKJ)
#s = 'mean rate = %0.1f Hz\nmean ISI = %0.1f ms\nISI std = %0.1f ms\nCV = %0.2f' % (mean(MR_PKJ.rate),mew,std,std/mew)
s = 'mean rate = %0.0f Hz\nCV = %0.2f' % (mean(MR_PKJ.rate),std/mew)
annotate(s,(20,0),xytext=(60,MISI_PKJ.count.max()*.7),xycoords='data',fontsize=24)
tick_params(labelsize=20)
simpleaxis(ax)
xlabel('ISI (ms)', fontsize=20)
ylabel('Count', fontsize=20)
#title('PKJ ISI Histogram',fontsize=20)
xlim([0,140])
# Out:
# (0, 140)

# %% [markdown]
# <h2>Data analysis from parameter sweep</h2>

# %%
from pandas import *

# %%
with open('/home/bill/research/data/neuron_models/molecular_layer/bs_pkj_param_sweep/2013-05-15T08:56:24.340277/results.txt') as f:
    results = read_csv(f,delimiter='\t')

# %%
target = array([15.,.4,35.,.49])

# %%
results['error'] = ((results.ix[:,4:] - target).abs()/target).sum(axis=1)

# %%
results
# Out:
#     w_pkj_pkj  w_pkj_bs  w_bs_pkj  w_bs_bs  bs_mean_firing_rate     bs_cv  \
# 0         0.5       0.5       1.5      1.5            17.753125  0.271198
# 1         0.5       0.5       1.5      2.0            17.851042  0.271555
# 2         0.5       0.5       1.5      2.5            17.989583  0.265027
# 3         0.5       0.5       2.0      1.5            15.430208  0.341058
# 4         0.5       0.5       2.0      2.0            15.517708  0.342737
# 5         0.5       0.5       2.0      2.5            15.611458  0.335448
# 6         0.5       0.5       2.5      1.5            13.632292  0.440297
# 7         0.5       0.5       2.5      2.0            13.695833  0.439064
# 8         0.5       0.5       2.5      2.5            13.813542  0.423936
# 9         0.5       1.0       1.5      1.5            16.852083  0.284316
# 10        0.5       1.0       1.5      2.0            17.076042  0.282612
# 11        0.5       1.0       1.5      2.5            17.281250  0.276382
# 12        0.5       1.0       2.0      1.5            14.589583  0.365164
# 13        0.5       1.0       2.0      2.0            14.767708  0.358743
# 14        0.5       1.0       2.0      2.5            14.938542  0.352261
# 15        0.5       1.0       2.5      1.5            12.894792  0.453509
# 16        0.5       1.0       2.5      2.0            13.034375  0.454071
# 17        0.5       1.0       2.5      2.5            13.170833  0.443306
# 18        0.5       1.5       1.5      1.5            15.894792  0.312489
# 19        0.5       1.5       1.5      2.0            16.206250  0.304660
# 20        0.5       1.5       1.5      2.5            16.497917  0.296049
# 21        0.5       1.5       2.0      1.5            13.684375  0.389036
# 22        0.5       1.5       2.0      2.0            13.910417  0.381522
# 23        0.5       1.5       2.0      2.5            14.194792  0.372248
# 24        0.5       1.5       2.5      1.5            12.072917  0.483894
# 25        0.5       1.5       2.5      2.0            12.238542  0.481176
# 26        0.5       1.5       2.5      2.5            12.445833  0.460325
# 27        1.0       0.5       1.5      1.5            17.783333  0.267035
# 28        1.0       0.5       1.5      2.0            17.928125  0.266437
# 29        1.0       0.5       1.5      2.5            18.036458  0.263239
# 30        1.0       0.5       2.0      1.5            15.530208  0.340173
# 31        1.0       0.5       2.0      2.0            15.603125  0.340459
# 32        1.0       0.5       2.0      2.5            15.672917  0.332180
# 33        1.0       0.5       2.5      1.5            13.727083  0.428702
# 34        1.0       0.5       2.5      2.0            13.789583  0.425426
# 35        1.0       0.5       2.5      2.5            13.860417  0.425793
# 36        1.0       1.0       1.5      1.5            16.962500  0.284970
# 37        1.0       1.0       1.5      2.0            17.158333  0.283486
# 38        1.0       1.0       1.5      2.5            17.386458  0.277316
# 39        1.0       1.0       2.0      1.5            14.700000  0.368974
# 40        1.0       1.0       2.0      2.0            14.882292  0.355234
# 41        1.0       1.0       2.0      2.5            15.065625  0.349311
# 42        1.0       1.0       2.5      1.5            13.010417  0.452294
# 43        1.0       1.0       2.5      2.0            13.131250  0.448171
# 44        1.0       1.0       2.5      2.5            13.268750  0.439921
# 45        1.0       1.5       1.5      1.5            16.120833  0.306418
# 46        1.0       1.5       1.5      2.0            16.419792  0.303382
# 47        1.0       1.5       1.5      2.5            16.735417  0.292616
# 48        1.0       1.5       2.0      1.5            13.950000  0.384183
# 49        1.0       1.5       2.0      2.0            14.157292  0.374515
# 50        1.0       1.5       2.0      2.5            14.433333  0.370198
# 51        1.0       1.5       2.5      1.5            12.296875  0.480884
# 52        1.0       1.5       2.5      2.0            12.501042  0.458965
# 53        1.0       1.5       2.5      2.5            12.679167  0.453396
# 54        1.5       0.5       1.5      1.5            17.870833  0.265978
# 55        1.5       0.5       1.5      2.0            17.997917  0.261218
# 56        1.5       0.5       1.5      2.5            18.080208  0.262589
# 57        1.5       0.5       2.0      1.5            15.576042  0.341009
# 58        1.5       0.5       2.0      2.0            15.664583  0.338712
# 59        1.5       0.5       2.0      2.5            15.729167  0.335161
# 60        1.5       0.5       2.5      1.5            13.792708  0.430285
# 61        1.5       0.5       2.5      2.0            13.856250  0.426331
# 62        1.5       0.5       2.5      2.5            13.902083  0.423412
# 63        1.5       1.0       1.5      1.5            17.116667  0.285544
# 64        1.5       1.0       1.5      2.0            17.279167  0.277703
# 65        1.5       1.0       1.5      2.5            17.496875  0.271800
# 66        1.5       1.0       2.0      1.5            14.810417  0.357057
# 67        1.5       1.0       2.0      2.0            14.977083  0.352625
# 68        1.5       1.0       2.0      2.5            15.177083  0.350684
# 69        1.5       1.0       2.5      1.5            13.091667  0.457075
# 70        1.5       1.0       2.5      2.0            13.201042  0.444455
# 71        1.5       1.0       2.5      2.5            13.364583  0.430723
# 72        1.5       1.5       1.5      1.5            16.337500  0.299378
# 73        1.5       1.5       1.5      2.0            16.614583  0.294504
# 74        1.5       1.5       1.5      2.5            16.927083  0.283314
# 75        1.5       1.5       2.0      1.5            14.148958  0.377707
# 76        1.5       1.5       2.0      2.0            14.346875  0.373004
# 77        1.5       1.5       2.0      2.5            14.573958  0.366210
# 78        1.5       1.5       2.5      1.5            12.485417  0.467949
# 79        1.5       1.5       2.5      2.0            12.646875  0.460242
# 80        1.5       1.5       2.5      2.5            12.825000  0.447258
#
#     pkj_mean_firing_rate    pkj_cv     error
# 0              27.548958  0.260611  1.186576
# 1              23.888542  0.301528  1.213290
# 2              20.141667  0.356858  1.232979
# 3              28.873958  0.252548  0.835661
# 4              25.834375  0.282061  0.863911
# 5              22.609375  0.325176  0.892538
# 6              29.953125  0.240367  0.845575
# 7              27.286458  0.268718  0.856587
# 8              24.322917  0.302499  0.826652
# 9              27.927083  0.258194  1.087839
# 10             24.325000  0.296351  1.132076
# 11             20.678125  0.344581  1.167098
# 12             29.304167  0.248006  0.771055
# 13             26.309375  0.280175  0.795146
# 14             23.135417  0.316337  0.816846
# 15             30.268750  0.239677  0.920162
# 16             27.717708  0.263596  0.936332
# 17             25.005208  0.297831  0.907958
# 18             28.535417  0.253562  0.945659
# 19             25.059375  0.290884  1.009145
# 20             21.556250  0.338737  1.052546
# 21             29.832292  0.244197  0.764405
# 22             27.026042  0.272274  0.790999
# 23             23.916667  0.311129  0.804769
# 24             30.758333  0.236437  1.043540
# 25             28.296875  0.260181  1.047575
# 26             25.714583  0.293614  0.987177
# 27             25.390625  0.282954  1.215065
# 28             21.877083  0.328328  1.234000
# 29             18.434375  0.388137  1.225520
# 30             26.660417  0.270971  0.870187
# 31             23.710417  0.308671  0.881680
# 32             20.612500  0.354442  0.902130
# 33             27.559375  0.263077  0.832313
# 34             24.960417  0.296200  0.826615
# 35             22.376042  0.333181  0.821178
# 36             25.823958  0.281941  1.105193
# 37             22.496875  0.322930  1.133365
# 38             19.022917  0.378291  1.150272
# 39             27.078125  0.270565  0.771732
# 40             24.203125  0.303873  0.808096
# 41             21.211458  0.349772  0.811237
# 42             28.016667  0.262357  0.927476
# 43             25.507292  0.293777  0.916686
# 44             22.925000  0.324943  0.897071
# 45             26.167708  0.281693  0.986145
# 46             22.918750  0.320871  1.026537
# 47             19.490625  0.371516  1.069083
# 48             27.429167  0.267112  0.780727
# 49             24.671875  0.299910  0.802920
# 50             21.729167  0.338573  0.800484
# 51             28.369792  0.255456  1.050514
# 52             25.870833  0.287097  0.988932
# 53             23.365625  0.318547  0.970527
# 54             23.303125  0.317016  1.213669
# 55             20.038542  0.368033  1.223200
# 56             16.906250  0.427604  1.193178
# 57             24.610417  0.302721  0.864928
# 58             21.782292  0.344804  0.871492
# 59             18.993750  0.390200  0.871703
# 60             25.552083  0.293809  0.826530
# 61             23.129167  0.334228  0.799146
# 62             20.643750  0.374210  0.778210
# 63             23.766667  0.315839  1.103634
# 64             20.618750  0.361010  1.131824
# 65             17.367708  0.420064  1.133464
# 66             25.029167  0.297252  0.798242
# 67             22.278125  0.339357  0.790882
# 68             19.498958  0.382376  0.797623
# 69             25.953125  0.288213  0.940201
# 70             23.558333  0.324530  0.895666
# 71             21.114583  0.363657  0.840406
# 72             24.025000  0.308234  1.025245
# 73             20.978125  0.354188  1.049172
# 74             17.757292  0.411935  1.072152
# 75             25.204167  0.296854  0.786524
# 76             22.640625  0.333976  0.782572
# 77             19.927083  0.375917  0.776356
# 78             26.189583  0.288332  1.000806
# 79             23.869792  0.318124  0.976253
# 80             21.561458  0.357368  0.917782
