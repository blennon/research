# %% [markdown]
# <h1>Experiment #6 - Liu & Cull-Candy (2000)</h1>
# This experiment simulates a single MLI isolated from inhibitory synaptic current that fires spontaneously. The PF-MLI weights begin near equilibrium values. The experiment begins with a 2.5 second baseline period where the MLI and PFs fire spontaneously, followed by a simulated voltage clamp to hold the MLI at -60 mV. During the first 5 seconds, the PFs fire at a baseline rate of .33 Hz (according to Poisson statistics). Starting at 5 seconds, a parallel fiber bundle is then stimulated at 50 Hz (according to Poisson statistics) for several minutes.

# %%
# %load_ext autoreload
# %autoreload 2
import sys

sys.path.append("../../")
from brian import *
from neuron_models import *
from spiking_pf_mli_plasticity import *
import seaborn as sns
# Out:
# /home/bill/anaconda/lib/python2.7/site-packages/brian/utils/sparse_patch/__init__.py:39: UserWarning: Couldn't find matching sparse matrix patch for scipy version 0.14.0, but in most cases this shouldn't be a problem.
#   warnings.warn("Couldn't find matching sparse matrix patch for scipy version %s, but in most cases this shouldn't be a problem." % scipy.__version__)
# /home/bill/anaconda/lib/python2.7/site-packages/brian/synapses/spikequeue.py:490: UserWarning: Using C++ SpikeQueue
#   warnings.warn('Using C++ SpikeQueue')

# %%
save_results = True
exper_dir = '/home/bill/research/data/pf_mli_learning/experiment_6/'

N_GR = 8
eq_time = 5*second
trial_time = 1*second
stim_len = 1*second
base_rate = .33*Hz
stim_rate = 50*Hz
wmin = 0.2
        
def run_net(initial_weights):
    
    defaultclock.dt = .25*ms
    
    # set up the network
    pf_rates = build_pf_rates_func(eq_time, trial_time, N_GR, base_rate, stim_rate, stim_len)
    GR, MLI, S_GR_MLI = setup_isolated_mli_net(N_GR, initial_weights, pf_rates, wmin)

    @network_operation(Clock(dt=defaultclock.dt))
    def random_current():
        if defaultclock.t < 2.5*second:
            # spontaneous current during baseline
            MLI.I = gamma(3.966333,0.006653,size=len(MLI)) * nA
        else:
            # voltage clamp simulation
            MLI.V = -60 * mV
        
    # monitors
    GR_S, GR_R, MLI_V, MLI_S, MLI_R, W = setup_monitors(GR, MLI, S_GR_MLI)
    
    # plasticity
    @network_operation(defaultclock)
    def learn():
        update_weights(S_GR_MLI, GR_R, MLI_R, wmin)
        
    run(1*65*second)
    
    return GR_S, GR_R, MLI_V, MLI_S, MLI_R, W, S_GR_MLI.w[:,:]

# %%
GR_S, GR_R, MLI_V, MLI_S, MLI_R, W, w = run_net(.22*ones(N_GR))

if save_results:
    objects_dict = {'GR_S':GR_S, 'GR_R':GR_R, 'MLI_V':MLI_V, 
                'MLI_S':MLI_S,'MLI_R':MLI_R, 'W':W}
    pickle_results(objects_dict, exper_dir)

# %%
T_show_end = 10
fig = figure(figsize(20,14))
ax1, ax2, ax3, ax4 = plot_pf_mli_w_fig(MLI_V,MLI_S,MLI_R,GR_R,W,fig,defaultclock,T_show_end)
ax1.set_yticks(range(-80,20,20))
ax1.set_xticks(range(0,T_show_end+1,1))
ax2.set_yticks(range(0,90,30))
ax2.set_xticks(range(0,T_show_end+1,1))
ax3.set_xticks(range(0,T_show_end+1,1))
# Out:
# [<matplotlib.axis.XTick at 0xc05f9d0>,
#  <matplotlib.axis.XTick at 0xc06c5d0>,
#  <matplotlib.axis.XTick at 0xc2a4450>,
#  <matplotlib.axis.XTick at 0xc2a4990>,
#  <matplotlib.axis.XTick at 0xc2a4e90>,
#  <matplotlib.axis.XTick at 0xc2a65d0>,
#  <matplotlib.axis.XTick at 0xc2a6d10>,
#  <matplotlib.axis.XTick at 0xc2a7490>,
#  <matplotlib.axis.XTick at 0xc2a7bd0>,
#  <matplotlib.axis.XTick at 0xc2a7e50>,
#  <matplotlib.axis.XTick at 0xc2a9590>]

# %%
fig = figure(figsize(24,6))
plot_weights_by_trial(fig,W,trial_time,eq_time,1*ms)
title('Weight at end of trial',fontsize=22)
